# %%
### 사각형 클래스 만들기

class Square:
    def __init__(self):  # 생성자__init__의 매개변수의 첫번째는 self여야 합니다. 
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))  # 입력값을 int로 묶어야 합니다.

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')  # Square 클래스에 rect() 메서드를 추가합니다. 

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')  # Square 클래스에 par() 메서드를 추가합니다.  
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')  # Square 클래스에 trape() 메서드를 추가합니다. 
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

# %%
# 3,4를 입력해보세요
가로, 세로 = map(int,input('가로, 세로를 입력하세요. 예시 : 가로,세로').split(','))
print(가로, type(가로))
# Out:
# 가로, 세로를 입력하세요. 예시 : 가로,세로 3,4
# 3 <class 'int'>

# %%
def rect(self):  # 직사각형의 넓이를 구하는 메서드
    width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))  #가로, 세로를 입력받는 코드
    area = width * vertical  # 넓이를 구하는 부분
    result = '직사각형의 넓이는 : ' + str(area)
    return result

# %%
# 클래스 만들기 
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')


    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

# %%
# 객체 만들기 
a = Square()  # 1 입력하기
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>> 1
# 직사각형 함수는 rect()입니다.

# %%
# rect() 메서드 써보기
a.rect()
# Out:
# 가로, 세로를 입력하세요. 예시 : 가로,세로
#  >>> 3,4
# '직사각형의 넓이는 : 12'

# %%
# 문제 1. 평행사변형과 사다리꼴의 넓이를 구하는 메서드를 구현해봅시다. 

# 평행사변형 메서드
def par(self):
    result = self.width * self.height
    return result

# 사다리꼴 메서드
def trape(self):
    result = (self.top + self.bottom) * self.height / 2
    return result

# %%
# 사각형 넓이를 구하는 클래스 완성!
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        width, height = map(int, input('밑변, 높이를 입력하세요. 예시 : 밑변,높이\n >>>').split(','))
        area = width * height
        result = '평행사변형의 넓이는 : ' + str(area)
        return result

    def trape(self):
        top, bottom, height = map(int, input('윗변, 아랫변, 높이를 입력하세요. 예시 : 윗변,아랫변,높이\n >>>').split(','))
        area = (top + bottom) * height / 2
        result = '사다리꼴의 넓이는 : ' + str(area)
        return result


a = Square()  # 객체 생성
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>> 2
# 평행사변형 함수는 par()입니다.

# %%
# 평형사변형의 넓이
a.par()  # 3,2를 입력했을 때 넓이가 6이 나와야 합니다.
# Out:
# 밑변, 높이를 입력하세요. 예시 : 밑변,높이
#  >>> 3,2
# '평행사변형의 넓이는 : 6'

# %%
# 사다리꼴의 넓이
a.trape()  # 3,2,1 을 입력했을 때 넓이가 2.5이 나와야 합니다.
# Out:
# 윗변, 아랫변, 높이를 입력하세요. 예시 : 윗변,아랫변,높이
#  >>> 3,2,1
# '사다리꼴의 넓이는 : 2.5'

# %%
### 키오스크 만들기

# 주문 번호 코드로 출력   
print('⟝' + '-' * 30 + '⟞')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('상품명 : HOT 아메리카노') 
print('총 주문 금액 : 1500원')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('⟝' + '-' * 30 + '⟞')
# Out:
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# 상품명 : HOT 아메리카노
# 총 주문 금액 : 1500원
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞

# %%
# 커피 메뉴와 가격
coffee = ['americano', 'latte', 'mocha'] 
c_price = [2000, 3000, 3000]

# 논커피 메뉴와 가격
non_coffee = ['yuza_tea', 'green_tea', 'choco_latte']
n_price = [2500, 2500, 3000]

# %%
# 전체 메뉴와 가격 
menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]

# %%
# 논커피 메뉴와 가격을 출력해보세요.
print(menu[3:], price[3:])
# Out:
# ['yuza_tea', 'green_tea', 'choco_latte'] [2500, 2500, 3000]

# %%
# 문제 2-1. Kiosk 클래스를 생성합니다. 

class Kiosk:
    def __init__(self):
        self.menu = coffee + non_coffee
        self.price = c_price + n_price

# %%
a = Kiosk()  # 객체를 생성합니다.
a.menu  # 객체 속성을 출력합니다.
# Out:
# ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']

# %%
# 가격을 출력해보세요.
a.price
# Out:
# [2000, 3000, 3000, 2500, 2500, 3000]

# %%
# 메뉴판 출력하기

class Kiosk: 
    # 문제 2-1의 답을 입력하세요.     
    def __init__(self):
        self.menu = coffee + non_coffee
        self.price = c_price + n_price

# 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ' : ', self.price[i], '원')

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원

# %%
# 문제 2-2. 주문 메서드  
# 음료의 이름과 가격을 출력하세요.  

class Kiosk:
    def __init__(self):
        self.menu = coffee + non_coffee
        self.price = c_price + n_price
        self.price_sum = 0

    def menu_select(self):
        n = int(input("음료의 번호를 입력하세요 : "))
        self.price_sum = self.price[n-1]
        print(self.menu[n-1], ' : ', self.price[n-1], '원')


a = Kiosk()
a.menu_select()
# Out:
# 음료의 번호를 입력하세요 :  1
# americano  :  2000 원

# %%
# 주문 메서드   
def menu_select(self):
    n = 0
    while n < 1 or len(self.menu) < n:
        n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

        # 메뉴판에 있는 음료 번호일 때
        if 1 <= n and n <= len(self.menu):
            self.price_sum = self.price[n-1]  # 선택 음료의 가격
            print(self.menu[n-1], ' : ', self.price[n-1], '원')  # 메뉴

        # 메뉴판에 없는 번호일 때
        else:
            print("없는 메뉴입니다. 다시 주문해 주세요.")

# %%
class Kiosk:    
    def __init__(self):
        # 문제 2-1의 답을 입력하세요. 
        self.menu = coffee + non_coffee
        self.price = c_price + n_price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n & n <= len(self.menu):
                self.price_sum = self.price[n-1]  # 선택 음료의 가격
                # 문제 2-2의 답을 입력하세요. 
                print(self.menu[n-1], ' : ', self.price[n-1], '원')  # 메뉴
        
             # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")

# %%
# 아메리카노 주문해보기  
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 아메리카노 주문
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료 번호를 입력하세요 :  1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# 주문 음료 ICE americano  :  2000 원

# %%
# 문제 2-3. 주문 메서드      

# 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.

class Kiosk: 
    def __init__(self):
        # 문제 2-1의 답을 입력하세요. 
        self.menu = coffee + non_coffee
        self.price = c_price + n_price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n & n <= len(menu):
                self.price_sum = self.price[n-1]  # 선택 음료의 가격
        
            # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            temp = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3. 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.   
            # 힌트: if문을 활용해보세요.        
            t = 0
            t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

            if temp == 1:
                self.temp = "HOT"
            elif temp == 2:
                self.temp = "ICE"
            else:    
                print("1과 2 중 하나를 입력하세요.\n")
        # 문제 2-2의 답을 입력하세요. 
        print('주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원')

# %%
# 아이스 초코라떼 주문해보기  
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료 번호를 입력하세요 :  6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# 주문 음료 ICE choco_latte  :  3000 원

# %%
### 키오스크(Kiosk) 만들기 2

# %%
# 문제 3-1. 지불 메서드
# 위의 설명을 참고하여 pay 함수를 구현합니다. 

def pay(self):
    print(f"총 결제 금액은 {self.price_sum}원입니다.")

    pay_method = input("결제 수단을 선택하세요 (cash/1, card/2) : ").strip().lower()

    if pay_method == "cash" or pay_method == "1":
        print("직원을 호출하겠습니다.")
    elif pay_method == "card" or pay_method == "2":
        print("IC칩 방향에 맞게 카드를 꽂아주세요.")
    else:
        print("다시 결제를 시도해 주세요.")

# %%
Kiosk.pay = pay

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료 번호를 입력하세요 :  5
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  1
# 주문 음료 HOT green_tea  :  2500 원
# 총 결제 금액은 2500원입니다.
# 결제 수단을 선택하세요 (cash/1, card/2) :  2
# IC칩 방향에 맞게 카드를 꽂아주세요.

# %%
menu_temp = ['HOT americano', 'ICE latte', 'ICE mocha', 'ICE choco_latte'] 
price_temp = [2000, 3000, 3000, 3000] 

# 외곽
print('⟝' + '-' * 30 + '⟞')
for i in range(5):
    print('|' + ' ' * 31 + '|')

# 주문 상품명 : 해당 금액
for i in range(len(menu_temp)):
    print(menu_temp[i], ' : ', price_temp[i])

print('합계 금액 :', sum(price_temp))

# 외곽
for i in range(5):
    print('|' + ' ' * 31+ '|')
print('⟝' + '-' * 30 + '⟞')
# Out:
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# HOT americano  :  2000
# ICE latte  :  3000
# ICE mocha  :  3000
# ICE choco_latte  :  3000
# 합계 금액 : 11000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞

# %%
# 문제 3-2. 주문표 
# 위의 주문표 코드를 참고하여 table() 메서드를 작성해 봅니다. 

def table(self):
    print("\n" + "-" * 30)
    print("        주문표")
    print("-" * 30)

    for i in range(len(self.order)):
        print(self.order[i], ":", self.order_price[i], "원")

    print("-" * 30)
    print("총 주문 금액 :", sum(self.order_price), "원")
    print("-" * 30)

# %%
# 문제 3-3. 클래스 업데이트  
# 앞에서 구현했던 메서드들을 Kiosk 클래스에 추가합니다. 직접 코드를 작성해 보세요! 

class Kiosk:
    def __init__(self):
        self.menu = coffee + non_coffee
        self.price = c_price + n_price

        self.order = []         # 주문한 메뉴 이름 저장
        self.order_price = []   # 주문한 메뉴 가격 저장
        self.price_sum = 0      # 총 주문 금액
        self.temp = ""          # HOT / ICE

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ":", self.price[i], "원")

    # 주문 메서드
    def menu_select(self):
        n = 0

        # 번호 입력 받기 (예외처리 포함)
        while n < 1 or n > len(self.menu):
            n = int(input("음료 번호를 입력하세요 : "))

            if n < 1 or n > len(self.menu):
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 온도 선택
        t = 0
        while t != 1 and t != 2:
            t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

            if t == 1:
                self.temp = "HOT"
            elif t == 2:
                self.temp = "ICE"
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        # 주문 정보 저장
        self.order.append(self.menu[n - 1])
        self.order_price.append(self.price[n - 1])

        # 총합 업데이트
        self.price_sum = sum(self.order_price)

        # 주문 출력
        print("주문 음료", self.temp, self.menu[n - 1], ":", self.price[n - 1], "원")

    # 지불
    def pay(self):
        print(f"총 결제 금액은 {self.price_sum}원입니다.")

        pay_method = input("결제 수단을 선택하세요 (cash/1, card/2) : ").strip().lower()

        if pay_method == "cash" or pay_method == "1":
            print("직원을 호출하겠습니다.")
        elif pay_method == "card" or pay_method == "2":
            print("IC칩 방향에 맞게 카드를 꽂아주세요.")
        else:
            print("다시 결제를 시도해 주세요.")

    # 주문서 출력
    def table(self):
        print("\n" + "-" * 30)
        print("        주문표")
        print("-" * 30)

        for i in range(len(self.order)):
            print(self.order[i], ":", self.order_price[i], "원")

        print("-" * 30)
        print("총 주문 금액 :", sum(self.order_price), "원")
        print("-" * 30)

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano : 2000 원
# 2 latte : 3000 원
# 3 mocha : 3000 원
# 4 yuza_tea : 2500 원
# 5 green_tea : 2500 원
# 6 choco_latte : 3000 원
# 음료 번호를 입력하세요 :  3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# 주문 음료 ICE mocha : 3000 원
# 총 결제 금액은 3000원입니다.
# 결제 수단을 선택하세요 (cash/1, card/2) :  1
# 직원을 호출하겠습니다.
#
# ------------------------------
#         주문표
# ------------------------------
# mocha : 3000 원
# ------------------------------
# 총 주문 금액 : 3000 원
# ------------------------------
